# %% [markdown]
# # Task 15: Distributed Data Parallel (DDP) Multi-Node Sync Gateway
# Simulating distributed multi-process training loops with parameter gradient synchronization using GLOO backend.

# %%
import torch
from ddp_train import launch_ddp
print('DDP Distributed Gateway ready.')
# Out:
# DDP Distributed Gateway ready.

# %%
# Launch 2 simulated distributed node processes
launch_ddp()
