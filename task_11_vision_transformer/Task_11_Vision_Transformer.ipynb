# %% [markdown]
# # Task 11: Vision Transformer (ViT) Patch Projection & Attention
# Building Vision Transformer from scratch with linear patch projection, CLS token, and multi-head attention.

# %%
import torch
import matplotlib.pyplot as plt
from vision_transformer_scratch import SimpleViT, visualize_attn
print('ViT module initialized.')
# Out:
# ViT module initialized.

# %%
# Forward pass through Vision Transformer
img = torch.randn(2, 3, 32, 32)
vit = SimpleViT()
out, attn = vit(img)
print(f'Input Image shape: {img.shape} -> ViT Output shape: {out.shape}')
# Out:
# Input Image shape: torch.Size([2, 3, 32, 32]) -> ViT Output shape: torch.Size([2, 17, 64])

# %%
# Plot multi-head self-attention matrix heatmap
visualize_attn()
img = plt.imread('vit_attention_map.png')
plt.figure(figsize=(4, 4))
plt.imshow(img)
plt.axis('off')
plt.show()
