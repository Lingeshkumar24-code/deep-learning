# %% [markdown]
# # Task 12: Conv Autoencoder Anomaly Detection
# Detecting structural defects using reconstruction error heatmaps from a Convolutional Autoencoder bottleneck.

# %%
import torch
import matplotlib.pyplot as plt
from autoencoder_anomaly_detection import ConvAutoencoder, run_anomaly_detection
print('Conv Autoencoder module ready.')
# Out:
# Conv Autoencoder module ready.

# %%
# Run anomaly detection inference
run_anomaly_detection()

# %%
# Display anomaly error heatmap plot
img = plt.imread('anomaly_error_heatmap.png')
plt.figure(figsize=(4, 4))
plt.imshow(img)
plt.axis('off')
plt.show()
