# %% [markdown]
# # Task 13: Temporal Convolutional Networks (TCN)
# Modeling time-series sequences using 1D dilated causal convolutions with zero temporal look-ahead leaks.

# %%
import torch
import matplotlib.pyplot as plt
from tcn_dilated_causal import SimpleTCN, forecast_demo
print('TCN forecasting module loaded.')
# Out:
# TCN forecasting module loaded.

# %%
# Run TCN forward pass on sequence tensor
x = torch.randn(8, 1, 50)
tcn = SimpleTCN()
pred = tcn(x)
print(f'Sequence Input: {x.shape} -> Forecasted Output: {pred.shape}')
# Out:
# Sequence Input: torch.Size([8, 1, 50]) -> Forecasted Output: torch.Size([8, 1])

# %%
# Plot time-series forecast plot
forecast_demo()
img = plt.imread('tcn_causal_forecast.png')
plt.figure(figsize=(6, 3))
plt.imshow(img)
plt.axis('off')
plt.show()
